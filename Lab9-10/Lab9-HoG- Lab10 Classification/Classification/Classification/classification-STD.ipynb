# %% [markdown]
# # Lab - Classification
#
# In this lab, we are going to build a classification module. When given an image of a handwritten digit like the one below, the model will be able to tell which digit is in the image.
#
# <img src='test2.jpg'>

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier  # MLP is an NN
from sklearn import svm
import numpy as np
import argparse
import imutils  # If you are unable to install this library, ask the TA; we only need this in extract_hsv_histogram.
import cv2
import os
import random


# Depending on library versions on your system, one of the following imports 
from sklearn.model_selection import train_test_split
#from sklearn.cross_validation import train_test_split

# %%
path_to_dataset = r'digits_dataset'
target_img_size = (32, 32) # fix image size because classification algorithms THAT WE WILL USE HERE expect that

# We are going to fix the random seed to make our experiments reproducible 
# since some algorithms use pseudorandom generators
random_seed = 42  
random.seed(random_seed)
np.random.seed(random_seed)

# %% [markdown]
# ## Part I - Feature Extraction
#
# In this part, we are going to implement three functions. Each one will extract a different set of features from the image. The three sets are:
#
# 1. Histogram of the pixel values features (this is the histogram you know, but on the HSV channels)
# 2. Histogram of Gradients (HoG) features
# 3. Raw pixels (basically, not doing any feature extraction and just supplying the input image to the classifier)

# %%
def extract_hsv_histogram(img):
    """
    TODO
    1. Resize the image to target_img_size using cv2.resize
    2. Convert the image from BGR representation (cv2 is BGR not RGB) to HSV using cv2.cvtColor
    3. Acquire the histogram using the cv2.calcHist. Apply the functions on the 3 channels. For the bins 
        parameter pass (8, 8, 8). For the ranges parameter pass ([0, 180, 0, 256, 0, 256]). Name the histogram
        <hist>.
    """
    img = cv2.resize(img, target_img_size)
    hsv_img = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
    hist = cv2.calcHist([hsv_img], [0, 1, 2], None, [8, 8, 8], [0, 180, 0, 256, 0, 256])
    
    if imutils.is_cv2():
        hist = cv2.normalize(hist)
    else:
        cv2.normalize(hist, hist)
    return hist.flatten()

# %%
def extract_hog_features(img):
    """
    TODO
    You won't implement anything in this function. You just need to understand it 
    and understand its parameters (i.e win_size, cell_size, ... etc)
    """
    img = cv2.resize(img, target_img_size)
    win_size = (32, 32)
    cell_size = (4, 4)
    block_size_in_cells = (2, 2)
    
    block_size = (block_size_in_cells[1] * cell_size[1], block_size_in_cells[0] * cell_size[0])
    block_stride = (cell_size[1], cell_size[0])
    nbins = 9  # Number of orientation bins
    hog = cv2.HOGDescriptor(win_size, block_size, block_stride, cell_size, nbins)
    h = hog.compute(img)
    h = h.flatten()
    return h.flatten()

# %%
def extract_raw_pixels(img):
    """
    TODO
    The classification algorithms we are going to use expect the input to be a vector not a matrix. 
    This is because they are general purpose and don't work only on images.
    CNNs, on the other hand, expect matrices since they operate on images and exploit the 
    arrangement of pixels in the 2-D space.
    
    So, what we only need to do in this function is to resize and flatten the image.
    """
    return cv2.resize(img, target_img_size).flatten()

# %%
def extract_features(img, feature_set='hog'):
    """
    TODO
    Given either 'hsv_hist', 'hog', 'raw', call the respective function and return its output
    """
    if feature_set == 'hsv_hist':
        return extract_hsv_histogram(img)
    elif feature_set == 'hog':
        return extract_hog_features(img)
    elif feature_set == 'raw':
        return extract_raw_pixels(img)

# %% [markdown]
# The following function will extract the features and the label of each image in our dataset and save it in RAM. We normally don't save datasets in RAM, but this dataset is small.

# %%
def load_dataset(feature_set='hog'):
    features = []
    labels = []
    img_filenames = os.listdir(path_to_dataset)

    for i, fn in enumerate(img_filenames):
        if fn.split('.')[-1] != 'jpg':
            continue

        label = fn.split('.')[0]
        labels.append(label)

        path = os.path.join(path_to_dataset, fn)
        img = cv2.imread(path)
        features.append(extract_features(img, feature_set))
        
        # show an update every 1,000 images
        if i > 0 and i % 1000 == 0:
            print("[INFO] processed {}/{}".format(i, len(img_filenames)))
        
    return features, labels

# %% [markdown]
# ## Part II - Classification
#
# In this part, we will test the classification performance of SVM, KNN, & NNs given our features.

# %%
# TODO understand the hyperparameters of each classifier
classifiers = {
    'SVM': svm.LinearSVC(random_state=random_seed),
    'KNN': KNeighborsClassifier(n_neighbors=7),
    'NN': MLPClassifier(solver='sgd', random_state=random_seed, hidden_layer_sizes=(500,), max_iter=20, verbose=1)
}

# %%
# This function will test all our classifiers on a specific feature set
def run_experiment(feature_set):
    
    # Load dataset with extracted features
    print('Loading dataset. This will take time ...')
    features, labels = load_dataset(feature_set)
    print('Finished loading dataset.')
    
    # Since we don't want to know the performance of our classifier on images it has seen before
    # we are going to withhold some images that we will test the classifier on after training 
    train_features, test_features, train_labels, test_labels = train_test_split(
        features, labels, test_size=0.2, random_state=random_seed)
    
    for model_name, model in classifiers.items():
        print('############## Training', model_name, "##############")
        # Train the model only on the training features
        model.fit(train_features, train_labels)
        
        # Test the model on images it hasn't seen before
        accuracy = model.score(test_features, test_labels)
        
        print(model_name, 'accuracy:', accuracy*100, '%')

# %% [markdown]
# Now, we see how each classifier and each feature set performs

# %%
run_experiment('hog')
"""
You should get the following test accuracies the first time 

SVM accuracy ~ 97.70833333333333
KNN accuracy ~ 96.52777777777779
NN accuracy ~ 93.95833333333333
"""
# Out:
# Loading dataset. This will take time ...
# [INFO] processed 1000/7200
# [INFO] processed 2000/7200
# [INFO] processed 3000/7200
# [INFO] processed 4000/7200
# [INFO] processed 5000/7200
# [INFO] processed 6000/7200
# [INFO] processed 7000/7200
# Finished loading dataset.
# ############## Training SVM ##############
# SVM accuracy: 97.70833333333333 %
# ############## Training KNN ##############
# KNN accuracy: 96.52777777777779 %
# ############## Training NN ##############
# Iteration 1, loss = 2.15704584
# Iteration 2, loss = 1.99560963
# Iteration 3, loss = 1.83560058
# Iteration 4, loss = 1.68165879
# Iteration 5, loss = 1.53364032
# Iteration 6, loss = 1.39346492
# Iteration 7, loss = 1.26395924
# Iteration 8, loss = 1.14686978
# Iteration 9, loss = 1.04253337
# Iteration 10, loss = 0.95068295
# Iteration 11, loss = 0.87050184
# Iteration 12, loss = 0.80047147
# Iteration 13, loss = 0.73942031
# Iteration 14, loss = 0.68650635
# Iteration 15, loss = 0.64004929
# Iteration 16, loss = 0.59965613
# Iteration 17, loss = 0.56371149
# Iteration 18, loss = 0.53196620
# Iteration 19, loss = 0.50386822
# Iteration 20, loss = 0.47872302
# NN accuracy: 93.95833333333333 %
# C:\Users\LENOVO\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (20) reached and the optimization hasn't converged yet.
#   warnings.warn(
# '\nYou should get the following test accuracies the first time \n\nSVM accuracy ~ 97.70833333333333\nKNN accuracy ~ 96.52777777777779\nNN accuracy ~ 93.95833333333333\n'

# %%
run_experiment('hsv_hist')
"""
You should get the following test accuracies the first time 

SVM accuracy ~ 32.083333333333336
KNN accuracy ~ 32.708333333333336
NN accuracy ~ 9.722222222222223
"""

# Why low accuracies? 
# histogram takes into account color distribution only, and ignores localization/shape, which is poor for a dataset like this.
# Out:
# Loading dataset. This will take time ...
# [INFO] processed 1000/7200
# [INFO] processed 2000/7200
# [INFO] processed 3000/7200
# [INFO] processed 4000/7200
# [INFO] processed 5000/7200
# [INFO] processed 6000/7200
# [INFO] processed 7000/7200
# Finished loading dataset.
# ############## Training SVM ##############
# SVM accuracy: 32.013888888888886 %
# ############## Training KNN ##############
# KNN accuracy: 32.708333333333336 %
# ############## Training NN ##############
# Iteration 1, loss = 2.20297167
# Iteration 2, loss = 2.20170845
# Iteration 3, loss = 2.20062078
# Iteration 4, loss = 2.19978368
# Iteration 5, loss = 2.19912285
# Iteration 6, loss = 2.19865292
# Iteration 7, loss = 2.19816292
# Iteration 8, loss = 2.19783041
# Iteration 9, loss = 2.19757067
# Iteration 10, loss = 2.19736311
# Iteration 11, loss = 2.19715509
# Iteration 12, loss = 2.19698755
# Iteration 13, loss = 2.19689621
# Iteration 14, loss = 2.19675860
# Iteration 15, loss = 2.19668040
# Iteration 16, loss = 2.19662019
# Iteration 17, loss = 2.19655556
# Iteration 18, loss = 2.19650088
# Iteration 19, loss = 2.19646341
# Iteration 20, loss = 2.19640426
# NN accuracy: 9.722222222222223 %
# C:\Users\LENOVO\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (20) reached and the optimization hasn't converged yet.
#   warnings.warn(
# '\nYou should get the following test accuracies the first time \n\nSVM accuracy ~ 32.083333333333336\nKNN accuracy ~ 32.708333333333336\nNN accuracy ~ 9.722222222222223\n'

# %%
run_experiment('raw')
"""
You should get the following test accuracies the first time 

SVM accuracy ~ 85.06944444444444
KNN accuracy ~ 93.95833333333333
NN accuracy ~ 88.68055555555556
"""
# Out:
# Loading dataset. This will take time ...
# [INFO] processed 1000/7200
# [INFO] processed 2000/7200
# [INFO] processed 3000/7200
# [INFO] processed 4000/7200
# [INFO] processed 5000/7200
# [INFO] processed 6000/7200
# [INFO] processed 7000/7200
# Finished loading dataset.
# ############## Training SVM ##############
# C:\Users\LENOVO\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\svm\_base.py:1235: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# SVM accuracy: 83.05555555555556 %
# ############## Training KNN ##############
# KNN accuracy: 93.95833333333333 %
# ############## Training NN ##############
# Iteration 1, loss = 9.85298309
# Iteration 2, loss = 1.53641950
# Iteration 3, loss = 1.39441295
# Iteration 4, loss = 1.22810570
# Iteration 5, loss = 1.09824867
# Iteration 6, loss = 0.98433061
# Iteration 7, loss = 0.95905031
# Iteration 8, loss = 0.82031770
# Iteration 9, loss = 0.75031226
# Iteration 10, loss = 0.48351466
# Iteration 11, loss = 0.38983886
# Iteration 12, loss = 0.33997489
# Iteration 13, loss = 0.30691439
# Iteration 14, loss = 0.26990163
# Iteration 15, loss = 0.27333650
# Iteration 16, loss = 0.24701966
# Iteration 17, loss = 0.22849889
# Iteration 18, loss = 0.21095051
# Iteration 19, loss = 0.21062550
# Iteration 20, loss = 0.19232647
# NN accuracy: 88.68055555555556 %
# C:\Users\LENOVO\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (20) reached and the optimization hasn't converged yet.
#   warnings.warn(
# '\nYou should get the following test accuracies the first time \n\nSVM accuracy ~ 85.06944444444444\nKNN accuracy ~ 93.95833333333333\nNN accuracy ~ 88.68055555555556\n'

# %% [markdown]
# The classifiers list now has models trained on the last feature set you ran an experiment on. You can play around with it checking the probability it gives to each label, given an image.

# %%
# Example
test_img_path = r'test2.jpg'
img = cv2.imread(test_img_path)
features = extract_features(img, 'raw')  # be careful of the choice of feature set

# %%
nn = classifiers['NN']
nn.predict_proba([features])
# Out:
# array([[1.30516918e-08, 9.93204966e-01, 6.76651988e-03, 8.76586162e-12,
#         6.12145342e-07, 1.85481749e-08, 2.78641382e-05, 1.20671458e-09,
#         4.52336788e-09]])

# %% [markdown]
# Try to get a better accuracy by changing the model hyperparameters and retraining.

# %%
classifiers = {
    'SVM': svm.LinearSVC(random_state=random_seed),
    'KNN': KNeighborsClassifier(n_neighbors=7),
    'NN': MLPClassifier(solver='sgd', random_state=random_seed, hidden_layer_sizes=(500,), max_iter=200, verbose=1)
}

# %%
run_experiment('hog')
# Out:
# Loading dataset. This will take time ...
# [INFO] processed 1000/7200
# [INFO] processed 2000/7200
# [INFO] processed 3000/7200
# [INFO] processed 4000/7200
# [INFO] processed 5000/7200
# [INFO] processed 6000/7200
# [INFO] processed 7000/7200
# Finished loading dataset.
# ############## Training SVM ##############
# SVM accuracy: 97.70833333333333 %
# ############## Training KNN ##############
# KNN accuracy: 96.52777777777779 %
# ############## Training NN ##############
# Iteration 1, loss = 2.15704584
# Iteration 2, loss = 1.99560963
# Iteration 3, loss = 1.83560058
# Iteration 4, loss = 1.68165879
# Iteration 5, loss = 1.53364032
# Iteration 6, loss = 1.39346492
# Iteration 7, loss = 1.26395924
# Iteration 8, loss = 1.14686978
# Iteration 9, loss = 1.04253337
# Iteration 10, loss = 0.95068295
# Iteration 11, loss = 0.87050184
# Iteration 12, loss = 0.80047147
# Iteration 13, loss = 0.73942031
# Iteration 14, loss = 0.68650635
# Iteration 15, loss = 0.64004929
# Iteration 16, loss = 0.59965613
# Iteration 17, loss = 0.56371149
# Iteration 18, loss = 0.53196620
# Iteration 19, loss = 0.50386822
# Iteration 20, loss = 0.47872302
# Iteration 21, loss = 0.45629442
# Iteration 22, loss = 0.43591907
# Iteration 23, loss = 0.41762980
# Iteration 24, loss = 0.40087429
# Iteration 25, loss = 0.38564783
# Iteration 26, loss = 0.37174221
# Iteration 27, loss = 0.35894327
# Iteration 28, loss = 0.34717542
# Iteration 29, loss = 0.33620599
# Iteration 30, loss = 0.32615223
# Iteration 31, loss = 0.31671946
# Iteration 32, loss = 0.30804531
# Iteration 33, loss = 0.29983375
# Iteration 34, loss = 0.29214885
# Iteration 35, loss = 0.28498544
# Iteration 36, loss = 0.27835672
# Iteration 37, loss = 0.27190533
# Iteration 38, loss = 0.26590922
# Iteration 39, loss = 0.26025643
# Iteration 40, loss = 0.25484404
# Iteration 41, loss = 0.24968004
# Iteration 42, loss = 0.24487721
# Iteration 43, loss = 0.24027133
# Iteration 44, loss = 0.23592676
# Iteration 45, loss = 0.23168903
# Iteration 46, loss = 0.22776417
# Iteration 47, loss = 0.22385388
# Iteration 48, loss = 0.22024645
# Iteration 49, loss = 0.21671553
# Iteration 50, loss = 0.21346658
# Iteration 51, loss = 0.21015944
# Iteration 52, loss = 0.20705558
# Iteration 53, loss = 0.20415243
# Iteration 54, loss = 0.20121360
# Iteration 55, loss = 0.19847800
# Iteration 56, loss = 0.19581964
# Iteration 57, loss = 0.19326159
# Iteration 58, loss = 0.19072844
# Iteration 59, loss = 0.18832442
# Iteration 60, loss = 0.18603292
# Iteration 61, loss = 0.18383415
# Iteration 62, loss = 0.18167306
# Iteration 63, loss = 0.17951895
# Iteration 64, loss = 0.17755547
# Iteration 65, loss = 0.17557934
# Iteration 66, loss = 0.17367912
# Iteration 67, loss = 0.17171592
# Iteration 68, loss = 0.16989557
# Iteration 69, loss = 0.16810446
# Iteration 70, loss = 0.16647821
# Iteration 71, loss = 0.16476257
# Iteration 72, loss = 0.16314533
# Iteration 73, loss = 0.16157102
# Iteration 74, loss = 0.16008187
# Iteration 75, loss = 0.15853667
# Iteration 76, loss = 0.15704603
# Iteration 77, loss = 0.15562113
# Iteration 78, loss = 0.15426739
# Iteration 79, loss = 0.15292870
# Iteration 80, loss = 0.15156668
# Iteration 81, loss = 0.15029532
# Iteration 82, loss = 0.14900320
# Iteration 83, loss = 0.14779470
# Iteration 84, loss = 0.14657336
# Iteration 85, loss = 0.14538803
# Iteration 86, loss = 0.14424405
# Iteration 87, loss = 0.14312601
# Iteration 88, loss = 0.14201892
# Iteration 89, loss = 0.14089105
# Iteration 90, loss = 0.13983168
# Iteration 91, loss = 0.13880939
# Iteration 92, loss = 0.13776973
# Iteration 93, loss = 0.13677387
# Iteration 94, loss = 0.13577332
# Iteration 95, loss = 0.13479822
# Iteration 96, loss = 0.13383960
# Iteration 97, loss = 0.13295480
# Iteration 98, loss = 0.13199611
# Iteration 99, loss = 0.13111767
# Iteration 100, loss = 0.13025390
# Iteration 101, loss = 0.12942870
# Iteration 102, loss = 0.12854031
# Iteration 103, loss = 0.12774321
# Iteration 104, loss = 0.12687690
# Iteration 105, loss = 0.12602917
# Iteration 106, loss = 0.12526520
# Iteration 107, loss = 0.12450383
# Iteration 108, loss = 0.12371696
# Iteration 109, loss = 0.12299013
# Iteration 110, loss = 0.12224257
# Iteration 111, loss = 0.12147486
# Iteration 112, loss = 0.12080591
# Iteration 113, loss = 0.12003184
# Iteration 114, loss = 0.11936839
# Iteration 115, loss = 0.11862776
# Iteration 116, loss = 0.11795387
# Iteration 117, loss = 0.11728619
# Iteration 118, loss = 0.11664660
# Iteration 119, loss = 0.11599020
# Iteration 120, loss = 0.11535100
# Iteration 121, loss = 0.11474696
# Iteration 122, loss = 0.11413408
# Iteration 123, loss = 0.11348937
# Iteration 124, loss = 0.11291019
# Iteration 125, loss = 0.11236488
# Iteration 126, loss = 0.11168677
# Iteration 127, loss = 0.11111748
# Iteration 128, loss = 0.11054854
# Iteration 129, loss = 0.10997049
# Iteration 130, loss = 0.10942630
# Iteration 131, loss = 0.10884622
# Iteration 132, loss = 0.10835771
# Iteration 133, loss = 0.10779239
# Iteration 134, loss = 0.10724709
# Iteration 135, loss = 0.10673047
# Iteration 136, loss = 0.10620723
# Iteration 137, loss = 0.10566936
# Iteration 138, loss = 0.10517440
# Iteration 139, loss = 0.10469544
# Iteration 140, loss = 0.10417328
# Iteration 141, loss = 0.10367912
# Iteration 142, loss = 0.10322878
# Iteration 143, loss = 0.10274757
# Iteration 144, loss = 0.10224246
# Iteration 145, loss = 0.10179289
# Iteration 146, loss = 0.10139196
# Iteration 147, loss = 0.10092069
# Iteration 148, loss = 0.10044644
# Iteration 149, loss = 0.10002008
# Iteration 150, loss = 0.09953341
# Iteration 151, loss = 0.09912991
# Iteration 152, loss = 0.09869375
# Iteration 153, loss = 0.09823853
# Iteration 154, loss = 0.09783242
# Iteration 155, loss = 0.09739790
# Iteration 156, loss = 0.09698021
# Iteration 157, loss = 0.09661079
# Iteration 158, loss = 0.09617377
# Iteration 159, loss = 0.09580118
# Iteration 160, loss = 0.09535762
# Iteration 161, loss = 0.09501079
# Iteration 162, loss = 0.09458622
# Iteration 163, loss = 0.09420876
# Iteration 164, loss = 0.09383691
# Iteration 165, loss = 0.09342936
# Iteration 166, loss = 0.09307862
# Iteration 167, loss = 0.09273595
# Iteration 168, loss = 0.09232045
# Iteration 169, loss = 0.09193576
# Iteration 170, loss = 0.09159081
# Iteration 171, loss = 0.09124162
# Iteration 172, loss = 0.09089046
# Iteration 173, loss = 0.09054276
# Iteration 174, loss = 0.09016109
# Iteration 175, loss = 0.08985725
# Iteration 176, loss = 0.08947749
# Iteration 177, loss = 0.08915113
# Iteration 178, loss = 0.08881528
# Iteration 179, loss = 0.08849806
# Iteration 180, loss = 0.08815835
# Iteration 181, loss = 0.08783332
# Iteration 182, loss = 0.08746042
# Iteration 183, loss = 0.08719703
# Iteration 184, loss = 0.08685252
# Iteration 185, loss = 0.08659844
# Iteration 186, loss = 0.08624818
# Iteration 187, loss = 0.08593509
# Iteration 188, loss = 0.08567474
# Iteration 189, loss = 0.08528473
# Iteration 190, loss = 0.08501615
# Iteration 191, loss = 0.08467509
# Iteration 192, loss = 0.08440786
# Iteration 193, loss = 0.08407497
# Iteration 194, loss = 0.08380629
# Iteration 195, loss = 0.08351552
# Iteration 196, loss = 0.08325444
# Iteration 197, loss = 0.08288223
# Iteration 198, loss = 0.08261230
# Iteration 199, loss = 0.08234235
# Iteration 200, loss = 0.08210035
# NN accuracy: 96.66666666666667 %
# C:\Users\LENOVO\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %%
random_seed = 24
random.seed(random_seed)
np.random.seed(random_seed)
classifiers = {
    'SVM': svm.LinearSVC(random_state=random_seed),
    'KNN': KNeighborsClassifier(n_neighbors=9),
    'NN': MLPClassifier(solver='sgd', random_state=random_seed, hidden_layer_sizes=(600,), max_iter=200, verbose=1)
}

# %%
run_experiment('hog')
# Out:
# Loading dataset. This will take time ...
# [INFO] processed 1000/7200
# [INFO] processed 2000/7200
# [INFO] processed 3000/7200
# [INFO] processed 4000/7200
# [INFO] processed 5000/7200
# [INFO] processed 6000/7200
# [INFO] processed 7000/7200
# Finished loading dataset.
# ############## Training SVM ##############
# SVM accuracy: 97.5 %
# ############## Training KNN ##############
# KNN accuracy: 97.01388888888889 %
# ############## Training NN ##############
# Iteration 1, loss = 2.17368958
# Iteration 2, loss = 2.01558526
# Iteration 3, loss = 1.86063187
# Iteration 4, loss = 1.71245182
# Iteration 5, loss = 1.56940256
# Iteration 6, loss = 1.43242370
# Iteration 7, loss = 1.30356740
# Iteration 8, loss = 1.18479697
# Iteration 9, loss = 1.07773092
# Iteration 10, loss = 0.98242788
# Iteration 11, loss = 0.89874873
# Iteration 12, loss = 0.82556127
# Iteration 13, loss = 0.76171678
# Iteration 14, loss = 0.70596035
# Iteration 15, loss = 0.65747876
# Iteration 16, loss = 0.61490937
# Iteration 17, loss = 0.57731844
# Iteration 18, loss = 0.54432518
# Iteration 19, loss = 0.51487985
# Iteration 20, loss = 0.48880996
# Iteration 21, loss = 0.46514033
# Iteration 22, loss = 0.44414955
# Iteration 23, loss = 0.42508817
# Iteration 24, loss = 0.40780488
# Iteration 25, loss = 0.39207304
# Iteration 26, loss = 0.37766385
# Iteration 27, loss = 0.36450737
# Iteration 28, loss = 0.35233225
# Iteration 29, loss = 0.34115051
# Iteration 30, loss = 0.33060223
# Iteration 31, loss = 0.32093438
# Iteration 32, loss = 0.31195451
# Iteration 33, loss = 0.30348112
# Iteration 34, loss = 0.29563615
# Iteration 35, loss = 0.28825153
# Iteration 36, loss = 0.28132458
# Iteration 37, loss = 0.27474229
# Iteration 38, loss = 0.26855187
# Iteration 39, loss = 0.26270440
# Iteration 40, loss = 0.25719450
# Iteration 41, loss = 0.25192922
# Iteration 42, loss = 0.24707556
# Iteration 43, loss = 0.24228268
# Iteration 44, loss = 0.23781614
# Iteration 45, loss = 0.23346675
# Iteration 46, loss = 0.22940388
# Iteration 47, loss = 0.22549457
# Iteration 48, loss = 0.22176672
# Iteration 49, loss = 0.21821819
# Iteration 50, loss = 0.21473988
# Iteration 51, loss = 0.21142284
# Iteration 52, loss = 0.20826970
# Iteration 53, loss = 0.20528623
# Iteration 54, loss = 0.20226724
# Iteration 55, loss = 0.19945578
# Iteration 56, loss = 0.19672755
# Iteration 57, loss = 0.19415167
# Iteration 58, loss = 0.19159402
# Iteration 59, loss = 0.18919085
# Iteration 60, loss = 0.18696208
# Iteration 61, loss = 0.18450997
# Iteration 62, loss = 0.18226627
# Iteration 63, loss = 0.18012964
# Iteration 64, loss = 0.17816997
# Iteration 65, loss = 0.17600685
# Iteration 66, loss = 0.17406288
# Iteration 67, loss = 0.17219304
# Iteration 68, loss = 0.17030878
# Iteration 69, loss = 0.16862212
# Iteration 70, loss = 0.16678009
# Iteration 71, loss = 0.16511926
# Iteration 72, loss = 0.16346074
# Iteration 73, loss = 0.16184312
# Iteration 74, loss = 0.16027375
# Iteration 75, loss = 0.15875352
# Iteration 76, loss = 0.15727293
# Iteration 77, loss = 0.15583654
# Iteration 78, loss = 0.15442398
# Iteration 79, loss = 0.15304777
# Iteration 80, loss = 0.15171674
# Iteration 81, loss = 0.15037892
# Iteration 82, loss = 0.14906284
# Iteration 83, loss = 0.14785688
# Iteration 84, loss = 0.14666444
# Iteration 85, loss = 0.14545801
# Iteration 86, loss = 0.14428859
# Iteration 87, loss = 0.14309756
# Iteration 88, loss = 0.14194713
# Iteration 89, loss = 0.14083823
# Iteration 90, loss = 0.13975584
# Iteration 91, loss = 0.13870007
# Iteration 92, loss = 0.13765909
# Iteration 93, loss = 0.13662495
# Iteration 94, loss = 0.13567660
# Iteration 95, loss = 0.13470107
# Iteration 96, loss = 0.13369040
# Iteration 97, loss = 0.13277800
# Iteration 98, loss = 0.13185641
# Iteration 99, loss = 0.13093872
# Iteration 100, loss = 0.13002754
# Iteration 101, loss = 0.12917258
# Iteration 102, loss = 0.12834933
# Iteration 103, loss = 0.12743105
# Iteration 104, loss = 0.12668159
# Iteration 105, loss = 0.12579997
# Iteration 106, loss = 0.12511088
# Iteration 107, loss = 0.12428245
# Iteration 108, loss = 0.12345393
# Iteration 109, loss = 0.12273327
# Iteration 110, loss = 0.12193208
# Iteration 111, loss = 0.12124196
# Iteration 112, loss = 0.12052755
# Iteration 113, loss = 0.11973784
# Iteration 114, loss = 0.11907714
# Iteration 115, loss = 0.11833464
# Iteration 116, loss = 0.11770953
# Iteration 117, loss = 0.11698693
# Iteration 118, loss = 0.11635466
# Iteration 119, loss = 0.11569826
# Iteration 120, loss = 0.11502632
# Iteration 121, loss = 0.11436632
# Iteration 122, loss = 0.11379921
# Iteration 123, loss = 0.11313407
# Iteration 124, loss = 0.11253270
# Iteration 125, loss = 0.11196617
# Iteration 126, loss = 0.11135517
# Iteration 127, loss = 0.11080267
# Iteration 128, loss = 0.11021670
# Iteration 129, loss = 0.10963244
# Iteration 130, loss = 0.10907691
# Iteration 131, loss = 0.10849451
# Iteration 132, loss = 0.10796005
# Iteration 133, loss = 0.10745165
# Iteration 134, loss = 0.10689228
# Iteration 135, loss = 0.10634355
# Iteration 136, loss = 0.10586187
# Iteration 137, loss = 0.10534246
# Iteration 138, loss = 0.10480874
# Iteration 139, loss = 0.10435120
# Iteration 140, loss = 0.10381232
# Iteration 141, loss = 0.10331903
# Iteration 142, loss = 0.10286141
# Iteration 143, loss = 0.10236688
# Iteration 144, loss = 0.10194086
# Iteration 145, loss = 0.10147467
# Iteration 146, loss = 0.10099930
# Iteration 147, loss = 0.10050457
# Iteration 148, loss = 0.10008076
# Iteration 149, loss = 0.09961285
# Iteration 150, loss = 0.09915811
# Iteration 151, loss = 0.09874320
# Iteration 152, loss = 0.09829362
# Iteration 153, loss = 0.09789321
# Iteration 154, loss = 0.09752100
# Iteration 155, loss = 0.09709689
# Iteration 156, loss = 0.09661970
# Iteration 157, loss = 0.09622181
# Iteration 158, loss = 0.09583089
# Iteration 159, loss = 0.09543803
# Iteration 160, loss = 0.09506914
# Iteration 161, loss = 0.09461903
# Iteration 162, loss = 0.09427451
# Iteration 163, loss = 0.09384841
# Iteration 164, loss = 0.09347510
# Iteration 165, loss = 0.09312146
# Iteration 166, loss = 0.09274831
# Iteration 167, loss = 0.09236656
# Iteration 168, loss = 0.09199630
# Iteration 169, loss = 0.09160870
# Iteration 170, loss = 0.09127312
# Iteration 171, loss = 0.09090465
# Iteration 172, loss = 0.09054130
# Iteration 173, loss = 0.09019837
# Iteration 174, loss = 0.08983986
# Iteration 175, loss = 0.08947555
# Iteration 176, loss = 0.08916084
# Iteration 177, loss = 0.08881351
# Iteration 178, loss = 0.08858890
# Iteration 179, loss = 0.08815191
# Iteration 180, loss = 0.08794206
# Iteration 181, loss = 0.08750228
# Iteration 182, loss = 0.08718163
# Iteration 183, loss = 0.08684349
# Iteration 184, loss = 0.08651957
# Iteration 185, loss = 0.08623953
# Iteration 186, loss = 0.08592504
# Iteration 187, loss = 0.08560267
# Iteration 188, loss = 0.08527022
# Iteration 189, loss = 0.08498643
# Iteration 190, loss = 0.08466907
# Iteration 191, loss = 0.08437793
# Iteration 192, loss = 0.08414297
# Iteration 193, loss = 0.08381566
# Iteration 194, loss = 0.08348193
# Iteration 195, loss = 0.08322814
# Iteration 196, loss = 0.08295310
# Iteration 197, loss = 0.08264806
# Iteration 198, loss = 0.08235628
# Iteration 199, loss = 0.08207908
# Iteration 200, loss = 0.08181264
# NN accuracy: 96.59722222222223 %
# C:\Users\LENOVO\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
